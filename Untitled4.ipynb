# %%
import pandas as pd

# Create the data exactly like the output
data = [
    [None, None, None, None],
    [None, None, None, None],
    [None, None, None, None],
    [None, None, None, None],
    [None, "Annual Returns on Investments in", None, None],
    ["Year", "Stocks", "T.Bills", "T.Bonds"],
    [1928, 0.4381, 0.0308, 0.0084],
    [1929, -0.0830, 0.0316, 0.0420],
    [1930, -0.2512, 0.0455, 0.0454],
    [1931, -0.4384, 0.0231, -0.0256]
]

# Create the DataFrame
df = pd.DataFrame(
    data,
    columns=["Unnamed: 0", "Unnamed: 1", "Unnamed: 2", "Unnamed: 3"]
)

# Save as a CSV file
df.to_csv("Historicalinvestemp.csv", index=False)

# Read the CSV file
df_csv = pd.read_csv("Historicalinvestemp.csv")

# Display the first 5 rows
df_csv.head()
# Out:
#   Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0        NaN                               NaN        NaN        NaN
# 1        NaN                               NaN        NaN        NaN
# 2        NaN                               NaN        NaN        NaN
# 3        NaN                               NaN        NaN        NaN
# 4        NaN  Annual Returns on Investments in        NaN        NaN
